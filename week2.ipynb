# %% [markdown]
# # DATA VISULIZATION

# %% [markdown]
# In this assignment , I am going to analyse the "Google Playstore Apps dataset".Before analyzing the data, First let's get to know the dataset.In this assignment, I am going to get hands-on experience with visual exploration of data using popular libraries such as pandas, matplotlib and seaborn.

# %% [markdown]
# # READING THE DATASET

# %%
#READING DATA
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
#SIZE OF THE DATASET
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.shape
# Out:
# (10841, 13)

# %%
#INFORMATION ABOUT THE DATASET
import pandas as pd
import numpy as np

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null int64
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10841 non-null object
# Genres            10841 non-null object
# Last Updated      10840 non-null object
# Current Ver       10833 non-null object
# Android Ver       10839 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# # DATA ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds['Installs']=ds['Installs'].apply(lambda a:a.split('+')[0])  
se=ds['Installs'].apply(lambda a:a.split(','))              

def add_list(x):
    sum=' '
    for i in range(0,len(x)):
        sum+=x[i]
    return int(sum)  

ds['Installs']=se.apply(lambda a:add_list(a)) 

ds['Type'].value_counts()

plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
sns.countplot(x='Type',data=ds)
plt.title("Number of Apps Available: Free v/s Paid")


plt.subplot(1,2,2)
sns.barplot(x='Type',y='Installs',data=ds,ci=None)
plt.title("Most installed: Free v/s Paid")
plt.tight_layout()

# %% [markdown]
# The first graph comapares the number of apps that are free and paid. The second graph shows the most installed apps are Free to install.

# %%
#PRICE DISTRIBUTION PIE CHART
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")


newPrice = []

for row in ds.Price:
    if row!= "0":
        newrow = float(row[1:])
    else:
        newrow = 0 
        
    newPrice.append(newrow)
        
ds.Price = newPrice

plt.pie(ds.Type.value_counts(), labels=['Free', 'Paid'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3d74defeb8>,
# ...
#  [Text(-1.070566794830964, 0.2527582596184673, 'Free'),
#   Text(1.0705667889147297, -0.2527582846768919, 'Paid')],
#  [Text(-0.5839455244532531, 0.13786814161007305, '92.6%'),
#   Text(0.5839455212262161, -0.13786815527830465, '7.4%')])

# %% [markdown]
# the above pie chart shows that 92.6% of the Apps are Free in the Play Store

# %%
#RATING GRAPH
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.dropna(inplace=True)
sns.distplot(ds.Rating)

# %% [markdown]
#  Most of the apps, clearly hold a rating above 4.0 And surprisingly a lot seem to have 5.0 rating.

# %%
#REVIEWS DISTRIBUTION GRAPH
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds.dropna(inplace=True)
plt.figure(figsize=(10,5))
sns.distplot(ds.Reviews)

# %% [markdown]
# The most famous Apps like WhatsApp, Facebook and Clash of Clans are the most reviewed Apps as shown above.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

playstore_data = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
paided = playstore_data[playstore_data['Type'] == 'Paid']
df3 = paided['Category'].value_counts()
df3 = df3.reset_index()
df3 = df3[:10]
plt.figure(figsize=(10,5))
plt.pie(x = list(df3['Category']), labels=list(df3['index']), autopct='%1.0f%%', pctdistance=0.8, labeldistance=1.2)
plt.title('% Distribution of Paided Apps Categories')
# Out:
# Text(0.5, 1.0, '% Distribution of Paided Apps Categories')

# %% [markdown]
# Distribution of Paided Apps Categories

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
plt.figure(figsize=(12,12))
sns.countplot(y='Category',data=ds)
plt.title("Number of Apps available based on Category")
# Out:
# Text(0.5, 1.0, 'Number of Apps available based on Category')

# %% [markdown]
# The above graph displays number of Apps available based on Catgeory. Maximum Number of Apps belong to the Family and Game Category

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds['Installs']=ds['Installs'].apply(lambda a:a.split('+')[0])   
se=ds['Installs'].apply(lambda a:a.split(','))                      

def add_list(x):
    sum=' '
    for i in range(0,len(x)):
        sum+=x[i]
    return int(sum)  

ds['Installs']=se.apply(lambda a:add_list(a)) 

plt.figure(figsize=(12,12))
sns.barplot(x='Installs',y='Category',data=ds,ci=None)
plt.title("Most installed based on Category")
# Out:
# Text(0.5, 1.0, 'Most installed based on Category')

# %% [markdown]
# The  graph shows the most installed apps based on category.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
plt.figure(figsize=(10,10))
sns.countplot(x='Content Rating',data=ds,)
plt.xticks(rotation=45)
plt.title("Number of Apps available based on Content rating")
# Out:
# Text(0.5, 1.0, 'Number of Apps available based on Content rating')

# %% [markdown]
# Number of Apps available based on Content rating

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds['Installs']=ds['Installs'].apply(lambda a:a.split('+')[0])   
se=ds['Installs'].apply(lambda a:a.split(','))                       

def add_list(x):
    sum=' '
    for i in range(0,len(x)):
        sum+=x[i]
    return int(sum)  

ds['Installs']=se.apply(lambda a:add_list(a)) 
plt.figure(figsize=(10,10))
sns.barplot(x='Content Rating',y='Installs',data=ds,ci=None)
plt.xticks(rotation=45)
plt.title("Number of Apps installed based on Content rating")
# Out:
# Text(0.5, 1.0, 'Number of Apps installed based on Content rating')

# %% [markdown]
# The graph shows the most installed apps based on content rating

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
plt.figure(figsize=(15,15))
sns.countplot(y='Android Ver',data=ds)
plt.title("Android Version's available")
# Out:
# Text(0.5, 1.0, "Android Version's available")

# %% [markdown]
# Number of apps installed based on android version

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds['Installs']=ds['Installs'].apply(lambda a:a.split('+')[0])  
se=ds['Installs'].apply(lambda a:a.split(','))                      

def add_list(x):
    sum=' '
    for i in range(0,len(x)):
        sum+=x[i]
    return int(sum)  

ds['Installs']=se.apply(lambda a:add_list(a)) 
plt.figure(figsize=(15,15))
sns.barplot(x='Installs',y='Android Ver',data=ds,ci=None)
plt.title("Android Versions of installed Apps")
# Out:
# Text(0.5, 1.0, 'Android Versions of installed Apps')

# %% [markdown]
# Most installed apps based on android version.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ds = pd.read_csv("/home/nbuser/library/assignment 1/googleplaystore.csv")
ds['Installs']=ds['Installs'].apply(lambda a:a.split('+')[0])   
se=ds['Installs'].apply(lambda a:a.split(','))                      

def add_list(x):
    sum=' '
    for i in range(0,len(x)):
        sum+=x[i]
    return int(sum)  

ds['Installs']=se.apply(lambda a:add_list(a)) 
plt.figure(figsize=(15,15))
sns.barplot(y='Installs',x='Rating',data=ds,ci=None)
plt.xticks(rotation=45)
plt.title("Number of Apps and ratings ")
# Out:
# Text(0.5, 1.0, 'Number of Apps and ratings ')

# %% [markdown]
# Ratings of Apps and the number of installed

# %% [markdown]
# # RESULT

# %%
1.We have got 8886 apps to analyze for their ratings and performance.
2.Most of the apps, clearly hold a rating above 4.0 according to the graph And surprisingly a lot seem to have 5.0 rating.
3.There are 271 Apps in the store which hold 5.0 Ratings.
4.The most famous Apps like WhatsApp, Facebook and Clash of Clans are the most reviewed Apps.
5.92.6% of the Apps are Free in the Play Store.
6.The most costly App in the Store is: I'm Rich - Trump Edition costing 400 Dollars.
7.Most of the apps support Android 4.0 and above.
8.Most of the are for every  age group according to the content rating graph.
9. Apps related to Education, LifeStyle and Tools seem to fetch full Ratings with sufficient number of reviews.
10.All the Apps with 5.0 ratings are Free to install.
